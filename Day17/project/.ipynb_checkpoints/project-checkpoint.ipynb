# %%
import random
from question_model import Question
from quiz_brain import QuizBrain
from quiz_data import question_data, question_data_api

question_bank = []


for question in question_data:
    question_bank.append(Question(question['text'], question['answer']))

for question in question_data_api:
    question_bank.append(Question(question['question'], question['correct_answer']))

quiz = QuizBrain(question_bank)

while quiz.still_has_questions():
    quiz.next_question()

print("You've completed the quiz!!!")
print(f"Your final score was: {quiz.score}/{len(question_bank)}")
# Out:
# Q.1: A slug's blood is green.? (True/False): False
# That's wrong.
# The correct answer was: True.
# Your current score is: 0/1
#
# Q.2: Самое громкое животное - африканский слон.? (Верно / Неверно):True
# That's wrong.
# The correct answer was: False.
# Your current score is: 0/2
#
# Вопрос 3: Примерно четверть человеческих костей находится в стопах.? (Верно / Неверно):True
# You got it right!
# The correct answer was: True.
# Your current score is: 1/3
#
# В.4: Общая площадь легких человека равна размеру футбольного поля.? (Верно / Неверно):True
# You got it right!
# The correct answer was: True.
# Your current score is: 2/4
#
# Вопрос 5: В Западной Вирджинии, США, если вы случайно сбили животное своей машиной, вы можете забрать его домой, чтобы поесть. (Верно / Неверно):True
# You got it right!
# The correct answer was: True.
# Your current score is: 3/5
#
# ...

# %% [markdown]
# # Контрольный опрос
# инструкции
# Создайте Questionкласс в question_model.py с __init__()методом с двумя атрибутами:
# text
# answer
#
# Создайте question_bankсписок объектов вопросов с данными из quiz_data.py в project.py .
#
# В файле quiz_brain.py создайте класс, который:
#
# Задавай вопросы
#
# Проверьте правильность ответа
#
# Вы прошли викторину?
#
# Используйте созданные классы для выполнения викторины со всеми вопросами в project.py .
#
# Используйте данные с https://opentdb.com/ с помощью API.
