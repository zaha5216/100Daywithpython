# %% [markdown]
# # Игра черепахи
# инструкции
# Сложность Нормальная: Используйте все шаги, чтобы завершить проект.
#  Сложная сложность: используйте только шаги 1 и 2 для завершения проекта.
#
#  Специалист по сложности: используйте только шаг 1 для завершения проекта.
#
# Шаг 1
# Черепаха движется вперед, когда вы нажимаете клавишу «Вверх». Он может двигаться только вперед, но не назад, влево или вправо.
#
# Шаг 2
# Машины генерируются случайным образом по оси Y и перемещаются от правого края экрана к левому краю.
#
# Шаг 3
# Когда черепаха попадает в верхний край экрана, она возвращается в исходное положение, и уровень игрока повышается. На следующем уровне скорость автомобиля увеличивается.
#
# Шаг 4
# Когда черепаха сталкивается с машиной, игра заканчивается и все останавливается.
#
# Шаг 5
# Создайте игрока с черепахой, который запускается в нижней части экрана и слушайте нажатие клавиши «Вверх», чтобы переместить черепаху на север. Если вы застряли, посмотрите видео-пошаговое руководство на шаге 3.
#
# ШАГ 6
# Создайте автомобили высотой 20 пикселей и шириной 40 пикселей, которые случайным образом генерируются вдоль оси Y и перемещаются к левому краю экрана. В верхних и нижних 50px экрана не должно быть машин (считайте это безопасной зоной для нашей маленькой черепахи). Подсказка: создавайте новую машину только каждый 6-й раз, когда запускается игровой цикл. Если вы застряли, посмотрите видео-пошаговое руководство на шаге 4.
#
# Шаг 7.
# Определите, когда игрок-черепаха сталкивается с автомобилем, и остановите игру, если это произойдет. Если вы застряли, посмотрите видео-пошаговое руководство на шаге 5.
#
# Шаг 8
# Определите, когда игрок-черепаха достиг верхнего края экрана (т. Е. Достиг FINISH_LINE_Y). Когда это произойдет, верните черепаху в исходное положение и увеличьте скорость машин. Подсказка: подумайте о создании атрибута и использовании MOVE_INCREMENT для увеличения скорости автомобиля. Если вы застряли, посмотрите видео-пошаговое руководство на шаге 6.
#
# Шаг 9
# Создайте табло, которое отслеживает, на каком уровне находится пользователь. Каждый раз, когда игрок-черепаха совершает успешный переход, уровень должен повышаться. Когда черепаха попадает в машину, в центре должна отображаться надпись «ИГРА КОНЕЦ». Если вы застряли, посмотрите видео-пошаговое руководство на шаге 7.

# %% [markdown]
# import time
# import random
# from turtle import Screen
# from player import Player
# from car_manager import CarManager
# from scoreboard import Scoreboard
#
# screen = Screen()
# screen.setup(width=600, height=600)
# screen.tracer(0)
#
# player = Player()
# scoreboard = Scoreboard()
#
# screen.listen()
# screen.onkeypress(player.move, 'Up')
#
# game_is_on = True
# count = 0
# car_manager = CarManager()
#
# while game_is_on:
#     count += 1
#     if count % 6 == 0:
#         car_manager.create_car()
#     car_manager.move_cars()
#     time.sleep(0.1)
#     screen.update()
#     random.shuffle(car_manager.all_cars)
#     if player.end_line():
#         scoreboard.update_level()
#         player.goto_beginning()
#         car_manager.update_level()
#
#     if car_manager.check_collision(player):
#         game_is_on = False
#         scoreboard.game_over()
#
#
#
# screen.exitonclick()

# %%
import time
import random
from turtle import Screen
from player import Player
from car_manager import CarManager
from scoreboard import Scoreboard

screen = Screen()
screen.setup(width=600, height=600)
screen.tracer(0)

player = Player()
scoreboard = Scoreboard()

screen.listen()
screen.onkeypress(player.move, 'Up')

game_is_on = True
count = 0
car_manager = CarManager()

while game_is_on:
    count += 1
    if count % 6 == 0:
        car_manager.create_car()
    car_manager.move_cars()
    time.sleep(0.1)
    screen.update()
    random.shuffle(car_manager.all_cars)
    if player.end_line():
        scoreboard.update_level()
        player.goto_beginning()
        car_manager.update_level()

    if car_manager.check_collision(player):
        game_is_on = False
        scoreboard.game_over()



screen.exitonclick()
